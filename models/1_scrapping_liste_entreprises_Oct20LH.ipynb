# %% [markdown]
# <h1> 0. Scrapping de la liste des entreprises </h1>
# <h3> Structure du site </h3>
# page principale
#     catégories
#         liste des entreprises notées
#             page des entreprises avec impression des avis
#
# <h3> Stratégie de scrappping </h3>
#
# 1) Choisir une catégorie
# 2) Scrap 1 : depuis la page des listes de entreprises:
#     scrapper:
# - nom de l'entreprise
# - trust score
# - nombre d'avis
# - lien vers la page de l'entreprise
#
# <u> -> Sauvegarder comme df/csv "liste_entreprises" </u>

# %%
# librairies
import requests
import lxml
from bs4 import BeautifulSoup
import pandas as pd
import random
import math

# %% [markdown]
# <h1> Catégorie de test: Immobilier </h1>
# pour tester j'essaie avec la catégorie immobilier qui a de nombreuses entreprises et beaucoup d'avis et un métier qui me semble assez riche.

# %% [markdown]
# <h1> 0. Scrapping de la liste des entreprises immobilières </h1>

# %%
# Aquisition de la page catégorie immobilier
# structure de la page

"""
page principale immo: https://fr.trustpilot.com/categories/real_estate_agents
il y a 5 pages, je vais préparer une for loop sur 5 pages

Les avis immo sont trop déséquilibrés (4 ou 5 étoiles ++)
page principale banque: https://fr.trustpilot.com/categories/bank

"""
# page de départ
url = "https://fr.trustpilot.com/categories/bank"
# clé de page qui se rajoute à l'URL de départ 
clé_pages = "?page="

# %%
# aquisition de la page
print(scrap_url)
immo = requests.get(scrap_url)
soup = BeautifulSoup(immo.content, "lxml")

n_entreprises = soup.find("p", class_ = "typography_body-m__xgxZ_ typography_appearance-default__AAY17")
n_entreprises = int(n_entreprises.text.split(sep=" ")[2])
n_pages_ent = n_pages = math.ceil(n_entreprises / 20)

cartes_entreprises = soup.find_all("div", class_ = "paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2")
nom_html = cartes_entreprises[1].find("p", class_="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2")

bulk_url_page_entreprise = soup.find("a", attrs={"name":"business-unit-card",
                                                        "target": "_self",
                                                        "class":"link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j"})

bulk_url_page_entreprise["href"]
# Out:
# https://fr.trustpilot.com/categories/bank?page=1
# '/review/immopret.fr'

# %%
# test de process des 5 pages
"""
Probleme a partr de la page 4, il n'y a qu'un score et n avis tandis que les autres variables
ont une longueur de 20
Solution: remplir les echecs de scrap par des NA? à moins qu'il n'y ait qu'une 
balise de ce type sur cette page, auquel cas, voir comment capturer l'ancienne version et merge?
"""

liste_entreprises = pd.DataFrame()

# aquisition de la page
print(url)
immo = requests.get(url)
soup = BeautifulSoup(immo.content, "lxml")

n_entreprises = soup.find("p", class_ = "typography_body-m__xgxZ_ typography_appearance-default__AAY17")
n_entreprises = int(n_entreprises.text.split(sep=" ")[2])
n_pages_ent = n_pages = math.ceil(n_entreprises / 20)

# tourne tant que le décompte et plus petit que le nombre de pages souhaitées
for ent_pages in range(0,n_pages_ent):
    # définition de l'url de la page
    scrap_url = url+clé_pages+str(ent_pages)
    # aquisition de la page
    print(scrap_url)
    html = requests.get(scrap_url)
    soup = BeautifulSoup(html.content, "lxml")
    
    cartes_entreprises = soup.find_all("div", class_ = "paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2")
    for carte in cartes_entreprises:
        # extraction des noms des entreprises
        nom = []
        nom_html = carte.find("p", class_="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2")
        if nom_html is not None:
            nom.append(nom_html.text)
        else:
            nom.append("na")
        # extraction de l'ensemble score et avis
        score,n_avis, test = [],[],[]

        # score bis

        score_html = carte.find("span", class_ = "typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ")
        if score_html is not None:
            score_html = score_html.text.replace("TrustScore ","")
            score.append(score_html)
        else:
            score.append("na")

        # avis
        avis_html = carte.find("p", class_ = "typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7")
        if avis_html is not None:
            avis_html = avis_html.text.split(" ")[1].split("|")[1]
            n_avis.append(avis_html)
        else:
            n_avis.append('na')

        # lien
        url_page_entreprise = []
        url_page_entreprise_html = carte.find("a", attrs={"name":"business-unit-card",
                                                        "target": "_self",
                                                        "class":"link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j"})
        if url_page_entreprise_html is not None:
            url_page_entreprise_html = url_page_entreprise_html["href"]
            url_page_entreprise.append(url_page_entreprise_html)
        else:
            url_page_entreprise.append('na')      

        # création de la dataframe
        print("juste avant création dataframe n")
        print("nom",nom,"\n","score", score,"\n", "n_avis",n_avis,"\n")
        liste_entreprise_temp = pd.DataFrame({"nom":nom,
                                "score": score,
                                "n_avis": n_avis,
                                "url_page_entreprise": url_page_entreprise})

        liste_entreprises = pd.concat([liste_entreprises,liste_entreprise_temp], ignore_index= True)
        liste_entreprise_temp = pd.DataFrame()
# Out:
# https://fr.trustpilot.com/categories/bank
# https://fr.trustpilot.com/categories/bank?page=0
# https://fr.trustpilot.com/categories/bank?page=1
# juste avant création dataframe n
# nom ['Immoprêt']
#  score ['4,9']
#  n_avis ['5\u202f305']
#
# juste avant création dataframe n
# nom ['CIB Formation']
#  score ['4,9']
#  n_avis ['519']
#
# juste avant création dataframe n
# nom ['Younited Credit']
#  score ['4,8']
#  n_avis ['64\u202f223']
#
# juste avant création dataframe n
# nom ['Pixpay']
#  score ['4,7']
#  n_avis ['4\u202f311']
#
# juste avant création dataframe n
# nom ['Cofidis']
#  score ['4,6']
#  n_avis ['19\u202f930']
#
# juste avant création dataframe n
# nom ['Anytime']
#  score ['4,6']
#  n_avis ['6\u202f859']
#
# juste avant création dataframe n
# nom ['Shine']
#  score ['4,5']
#  n_avis ['2\u202f427']
#
# juste avant création dataframe n
# nom ['Blank']
#  score ['4,5']
#  n_avis ['484']
#
# juste avant création dataframe n
# nom ['moneywalkie.com']
#  score ['4,5']
#  n_avis ['350']
#
# juste avant création dataframe n
# nom ['Helios.do']
#  score ['4,3']
#  n_avis ['484']
#
# juste avant création dataframe n
# nom ['propulsebyca.fr']
#  score ['4,3']
#  n_avis ['30']
#
# juste avant création dataframe n
# nom ['Monabanq']
#  score ['4,0']
#  n_avis ['4\u202f741']
#
# juste avant création dataframe n
# nom ['Fortuneo']
#  score ['3,9']
#  n_avis ['4\u202f757']
#
# juste avant création dataframe n
# nom ['Boursorama Banque']
#  score ['3,8']
#  n_avis ['6\u202f711']
#
# juste avant création dataframe n
# nom ['France SCPI - Le site tout en ligne de la SCPI']
#  score ['4,9']
#  n_avis ['274']
#
# juste avant création dataframe n
# nom ['ConnectBanque']
#  score ['4,8']
#  n_avis ['55']
#
# juste avant création dataframe n
# nom ['Kard']
#  score ['4,7']
#  n_avis ['1\u202f414']
#
# juste avant création dataframe n
# nom ['Vybe']
#  score ['4,7']
#  n_avis ['930']
#
# juste avant création dataframe n
# nom ['bcfinance.fr']
#  score ['4,7']
#  n_avis ['555']
#
# juste avant création dataframe n
# nom ['Louvre Banque Privée']
#  score ['4,7']
#  n_avis ['215']
#
# https://fr.trustpilot.com/categories/bank?page=2
# juste avant création dataframe n
# nom ['01 Banque en Ligne']
#  score ['4,7']
#  n_avis ['47']
#
# juste avant création dataframe n
# nom ['Green-Got']
#  score ['4,6']
#  n_avis ['336']
#
# juste avant création dataframe n
# nom ['Plusq1taux Landes Pays Basque']
#  score ['4,6']
#  n_avis ['18']
#
# juste avant création dataframe n
# nom ['ONLYONE']
#  score ['4,5']
#  n_avis ['35']
#
# juste avant création dataframe n
# nom ['PennyPet']
#  score ['4,5']
#  n_avis ['13']
#
# juste avant création dataframe n
# nom ['Orange Bank']
#  score ['4,4']
#  n_avis ['14\u202f222']
#
# juste avant création dataframe n
# nom ['Ma French Bank']
#  score ['4,3']
#  n_avis ['3\u202f126']
#
# juste avant création dataframe n
# nom ['la Nef']
#  score ['4,3']
#  n_avis ['74']
#
# juste avant création dataframe n
# nom ['MoneyNow']
#  score ['4,3']
#  n_avis ['9']
#
# juste avant création dataframe n
# nom ['Floabank']
#  score ['4,2']
#  n_avis ['7\u202f762']
#
# juste avant création dataframe n
# nom ['floapay.com']
#  score ['4,2']
#  n_avis ['25']
#
# juste avant création dataframe n
# nom ['Paykrom']
#  score ['4,1']
#  n_avis ['77']
#
# juste avant création dataframe n
# nom ['SOFINCO']
#  score ['3,8']
#  n_avis ['1\u202f282']
#
# juste avant création dataframe n
# nom ['Courtiers Privés']
#  score ['3,8']
#  n_avis ['27']
#
# juste avant création dataframe n
# nom ['Labanquepostale Sam']
#  score ['3,7']
#  n_avis ['62']
#
# juste avant création dataframe n
# nom ['Changer Ma Banque']
#  score ['3,7']
#  n_avis ['1']
#
# juste avant création dataframe n
# nom ['manager.one']
#  score ['3,6']
#  n_avis ['15']
#
# juste avant création dataframe n
# nom ['Hello bank! France']
#  score ['3,4']
#  n_avis ['1\u202f448']
#
# juste avant création dataframe n
# nom ['i p s']
#  score ['3,4']
#  n_avis ['308']
#
# juste avant création dataframe n
# nom ['qui-est-la-banque-la-moins-chere.com']
#  score ['3,2']
#  n_avis ['2']
#
# https://fr.trustpilot.com/categories/bank?page=3
# juste avant création dataframe n
# nom ['Carrefour Banque & Assurance']
#  score ['2,7']
#  n_avis ['801']
#
# juste avant création dataframe n
# nom ['LCL']
#  score ['2,6']
#  n_avis ['1\u202f279']
#
# juste avant création dataframe n
# nom ['Btocadvice']
#  score ['2,6']
#  n_avis ['4']
#
# juste avant création dataframe n
# nom ['Cosabnk']
#  score ['2,5']
#  n_avis ['10']
#
# juste avant création dataframe n
# nom ['BoursoBank']
#  score ['2,5']
#  n_avis ['6']
#
# juste avant création dataframe n
# nom ['Ma Banque BNP Paribas']
#  score ['2,3']
#  n_avis ['1\u202f886']
#
# juste avant création dataframe n
# nom ['Creditmutuel']
#  score ['2,2']
#  n_avis ['1\u202f023']
#
# juste avant création dataframe n
# nom ['CASDEN Banque Populaire']
#  score ['2,2']
#  n_avis ['12']
#
# juste avant création dataframe n
# nom ['BforBank']
#  score ['2,1']
#  n_avis ['496']
#
# juste avant création dataframe n
# nom ['SolutionBancaire.fr']
#  score ['2,1']
#  n_avis ['98']
#
# juste avant création dataframe n
# nom ['Oney']
#  score ['2,0']
#  n_avis ['4\u202f675']
#
# juste avant création dataframe n
# nom ['ZELF']
#  score ['2,0']
#  n_avis ['60']
#
# juste avant création dataframe n
# nom ['Société Générale & Vous']
#  score ['1,7']
#  n_avis ['1\u202f776']
#
# juste avant création dataframe n
# nom ['franfinance.fr']
#  score ['1,6']
#  n_avis ['56']
#
# juste avant création dataframe n
# nom ['La Banque Postale']
#  score ['1,4']
#  n_avis ['3\u202f526']
#
# juste avant création dataframe n
# nom ['ING France']
#  score ['1,3']
#  n_avis ['291']
#
# juste avant création dataframe n
# nom ['TOP BANQUE']
#  score ['na']
#  n_avis ['na']
#
# juste avant création dataframe n
# nom ['WeBanking GmbH']
#  score ['na']
#  n_avis ['na']
#
# juste avant création dataframe n
# nom ['Bankifox']
#  score ['na']
#  n_avis ['na']
#
# juste avant création dataframe n
# nom ['Metalnews']
#  score ['na']
#  n_avis ['na']

# %%
liste_entreprises.sort_values('n_avis')
# Out:
#                                                nom score  n_avis  \
# 35                               Changer Ma Banque   3,7       1
# 43                                         Cosabnk   2,5      10
# 47                         CASDEN Banque Populaire   2,2      12
# 24                                        PennyPet   4,5      13
# 25                                     Orange Bank   4,4  14 222
# 36                                     manager.one   3,6      15
# 22                   Plusq1taux Landes Pays Basque   4,6      18
# 4                                          Cofidis   4,6  19 930
# 46                                    Creditmutuel   2,2   1 023
# 41                                             LCL   2,6   1 279
# 32                                         SOFINCO   3,8   1 282
# 16                                            Kard   4,7   1 414
# 37                              Hello bank! France   3,4   1 448
# 52                         Société Générale & Vous   1,7   1 776
# 45                           Ma Banque BNP Paribas   2,3   1 886
# 39            qui-est-la-banque-la-moins-chere.com   3,2       2
# 19                            Louvre Banque Privée   4,7     215
# 30                                     floapay.com   4,2      25
# 33                                Courtiers Privés   3,8      27
# 14  France SCPI - Le site tout en ligne de la SCPI   4,9     274
# 55                                      ING France   1,3     291
# 6                                            Shine   4,5   2 427
# 10                                 propulsebyca.fr   4,3      30
# 38                                           i p s   3,4     308
# 21                                       Green-Got   4,6     336
# 23                                         ONLYONE   4,5      35
# 8                                  moneywalkie.com   4,5     350
# 26                                  Ma French Bank   4,3   3 126
# 54                               La Banque Postale   1,4   3 526
# 42                                      Btocadvice   2,6       4
# 20                              01 Banque en Ligne   4,7      47
# 7                                            Blank   4,5     484
# 9                                        Helios.do   4,3     484
# 48                                        BforBank   2,1     496
# 3                                           Pixpay   4,7   4 311
# 50                                            Oney   2,0   4 675
# 11                                        Monabanq   4,0   4 741
# 12                                        Fortuneo   3,9   4 757
# 1                                    CIB Formation   4,9     519
# 15                                   ConnectBanque   4,8      55
# 18                                    bcfinance.fr   4,7     555
# 53                                  franfinance.fr   1,6      56
# 0                                         Immoprêt   4,9   5 305
# 44                                      BoursoBank   2,5       6
# 51                                            ZELF   2,0      60
# 34                             Labanquepostale Sam   3,7      62
# 2                                  Younited Credit   4,8  64 223
# 13                               Boursorama Banque   3,8   6 711
# 5                                          Anytime   4,6   6 859
# 27                                          la Nef   4,3      74
# 31                                         Paykrom   4,1      77
# 29                                        Floabank   4,2   7 762
# 40                    Carrefour Banque & Assurance   2,7     801
# 28                                        MoneyNow   4,3       9
# 17                                            Vybe   4,7     930
# 49                             SolutionBancaire.fr   2,1      98
# 58                                        Bankifox    na      na
# 56                                      TOP BANQUE    na      na
# 57                                  WeBanking GmbH    na      na
# 59                                       Metalnews    na      na
#
#                              url_page_entreprise
# 35                   /review/changermabanque.com
# 43                           /review/cosabnk.com
# 47                             /review/casden.fr
# 24                           /review/pennypet.io
# 25                         /review/orangebank.fr
# 36                           /review/manager.one
# 22                        /review/plusq1taux.com
# 4                             /review/cofidis.fr
# 46                       /review/creditmutuel.fr
# 41                            /review/www.lcl.fr
# 32                            /review/sofinco.fr
# 16                               /review/kard.eu
# 37                          /review/hellobank.fr
# 52                /review/www.societegenerale.fr
# 45                    /review/www.bnpparibas.net
# 39  /review/qui-est-la-banque-la-moins-chere.com
# 19                                /review/bpe.fr
# 30                           /review/floapay.com
# 33              /review/www.courtiers-prives.com
# 14                    /review/www.francescpi.com
# 55                                /review/ing.fr
# 6                               /review/shine.fr
# 10                       /review/propulsebyca.fr
# 38                   /review/www.ips-payment.com
# 21                         /review/green-got.com
# 23                        /review/onlyonecard.eu
# 8                        /review/moneywalkie.com
# 26                   /review/www.mafrenchbank.fr
# 54                /review/www.labanquepostale.fr
# 42                        /review/btocadvice.com
# 20                  /review/01banque-en-ligne.fr
# 7                              /review/blank.app
# 9                              /review/helios.do
# 48                          /review/bforbank.com
# 3                              /review/pixpay.eu
# 50                               /review/oney.fr
# 11                      /review/www.monabanq.com
# 12                           /review/fortuneo.fr
# 1                        /review/cibformation.fr
# 15                     /review/connectbanque.com
# 18                          /review/bcfinance.fr
# 53                    /review/www.franfinance.fr
# 0                            /review/immopret.fr
# 44                        /review/boursobank.com
# 51                               /review/zelf.co
# 34            /review/www.labanquepostale-sam.fr
# 2                /review/www.younited-credit.com
# 13                 /review/boursorama-banque.com
# 5                               /review/anyti.me
# 27                         /review/www.lanef.com
# 31                       /review/www.paykrom.pro
# 29                           /review/floabank.fr
# 40               /review/www.carrefour-banque.fr
# 28                           /review/moneynow.fr
# 17                      /review/www.vybecard.com
# 49               /review/www.solutionbancaire.fr
# 58                          /review/bankifox.com
# 56                    /review/www.top-banque.com
# 57                          /review/webanking.fr
# 59                       /review/metalnews.press

# %%
# sauvegarder le df 
liste_entreprises.to_csv("../data/liste_entreprises_banque.csv")
