# %%
benchmark.columns
# Out:
# Index(['model', 'grid search', 'used/best params', 'score', 'precision',
#        'recall', 'f1', 'time_taken_mns', 'run_date'],
#       dtype='object')

# %%
# compiling Benchmark results
from os import listdir
import pandas as pd

bench_list = listdir("../reports/benchmark")
bench_list.remove(".DS_Store")

benchmark = pd.DataFrame()
for file in bench_list:
    df = pd.read_csv(f'../reports/benchmark/{file}', index_col=0)
    benchmark = pd.concat([benchmark, df])

new_cols = ['model', 'grid search', 'score', 'precision',
       'recall', 'f1', 'time_taken_mns', 'run_date', 'used/best params']
benchmark = benchmark.reindex(columns=new_cols)
benchmark.sort_values("f1", ascending = False)
# Out:
#                                                model grid search score  \
# 0      RF- GRID n_avis, sent, text length, companies         yes  0.55
# 0          XGB- n_avis, sent, text length, companies          no    na
# 0      XGBoost- n_avis, sent, text length, companies          no    na
# 0  XGBoost- GRID n_avis, sent, text length, compa...         yes  0.54
# 0  XGBoost_mac_mini- GRID n_avis, sent, text leng...         yes  0.54
# 0  XGBoost_mac_mini- n_avis, sent, text length, c...          no    na
# 0     XGB- GRID n_avis, sent, text length, companies         yes  0.54
# 0           RF- n_avis, sent, text length, companies          no  0.53
# 0  K-NN- GRID n_avis, sentiment, text length, com...         yes  0.51
# 0    K-NN- n_avis, sentiment, text length, companies          no  0.51
# 0  SVC- GRID n_avis, sentiment, text length, comp...         yes  0.51
# 0  LG- GRID n_avis, sentiment, text length, compa...         yes  0.49
# 0  LG - GRID n_avis, sentiment, text length, comp...          no  0.49
# 0      LG- n_avis, sentiment, text length, companies          no  0.49
# 0      LG- n_avis, sentiment, text length, companies          no  0.49
# 0     SVC- n_avis, sentiment, text length, companies          no   0.5
# 0  RF- GRID TFIDF, n_avis, sent, text length, com...         yes  0.47
# 0  XGBoost_mac_mini-TFIDF, n_avis, sent, text len...          no    na
# 0  XGBoost-TFIDF, n_avis, sent, text length, comp...          no    na
# 0  K-NN- GRID text TFIDF, n_avis, sentiment, text...         yes  0.46
# 0  LG- GRID text TFIDF, n_avis, sentiment, text l...         yes  0.45
# 0  K-NN - GRID n_avis, sentiment, text length, co...          no  0.45
# 0    RF- TFIDF, n_avis, sent, text length, companies          no  0.42
#
#    precision  recall    f1  time_taken_mns    run_date  \
# 0       0.55    0.55  0.55            9.41  2024-02-07
# 0       0.54    0.54  0.54            0.01  2024-02-07
# 0       0.54    0.54  0.54            0.02  2024-02-07
# 0       0.54    0.54  0.54           80.05  2024-02-07
# 0       0.54    0.54  0.54           34.91  2024-02-07
# 0       0.54    0.54  0.54            0.01  2024-02-07
# 0       0.54    0.54  0.54          168.30  2024-02-07
# 0       0.52    0.53  0.52            0.00  2024-02-07
# 0       0.51    0.51  0.51            1.74  2024-02-07
# 0       0.50    0.51  0.50            0.00  2024-02-07
# 0       0.50    0.51  0.50            6.05  2024-02-07
# 0       0.49    0.49  0.49            0.62  2024-02-08
# 0       0.49    0.49  0.49            0.00  2024-02-08
# 0       0.49    0.49  0.49            0.01  2024-02-08
# 0       0.49    0.49  0.49            0.01  2024-02-08
# 0       0.49    0.50  0.49            0.13  2024-02-07
# 0       0.47    0.47  0.47           11.39  2024-02-07
# 0       0.47    0.48  0.47            0.15  2024-02-07
# 0       0.47    0.48  0.47            0.41  2024-02-07
# 0       0.46    0.46  0.46            6.89  2024-02-07
# 0       0.45    0.45  0.45            4.17  2024-02-08
# 0       0.45    0.45  0.44            0.00  2024-02-07
# 0       0.41    0.42  0.38            0.00  2024-02-07
#
#                                     used/best params
# 0  {'max_depth': None, 'min_samples_leaf': 2, 'mi...
# 0                           baseline hyperparameters
# 0                           baseline hyperparameters
# 0  {'colsample_bytree': 0.7, 'gamma': 0.1, 'learn...
# 0  {'colsample_bytree': 0.7, 'gamma': 0.1, 'learn...
# 0                           baseline hyperparameters
# 0  {'colsample_bytree': 0.7, 'gamma': 0.1, 'learn...
# 0                           baseline hyperparameters
# 0  {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...
# 0                           baseline hyperparameters
# 0         {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0      {'C': 100, 'l1_ratio': 0.1, 'solver': 'saga'}
# 0                           baseline hyperparameters
# 0                           baseline hyperparameters
# 0                           baseline hyperparameters
# 0                           baseline hyperparameters
# 0  {'max_depth': None, 'min_samples_leaf': 2, 'mi...
# 0                           baseline hyperparameters
# 0                           baseline hyperparameters
# 0  {'algorithm': 'brute', 'leaf_size': 10, 'n_nei...
# 0     {'C': 1000, 'l1_ratio': 0.1, 'solver': 'saga'}
# 0                           baseline hyperparameters
# 0                           baseline hyperparameters
